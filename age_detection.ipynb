# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Ebadi/Age-Detection/blob/main/age_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install model
# Out:
# ERROR: Could not find a version that satisfies the requirement model (from versions: none)
# ERROR: No matching distribution found for model

# %%
# !pip install better_exceptions

# %%
# !pip install pretrainedmodels
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 966.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=8fb01ee9fa947576b145556049ebec1ce4b7dff81ea03132708a454ceaac0b72
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built pretrainedmodels
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/colab/Pgu-Face_Part1.zip -d /content/drive/MyDrive/colab/train
# !unzip /content/drive/MyDrive/colab/Pgu-Face_Part2.zip -d /content/drive/MyDrive/colab/train
# !unzip /content/drive/MyDrive/colab/Pgu-Face_Part3.zip -d /content/drive/MyDrive/colab/train
# !unzip /content/drive/MyDrive/colab/Pgu-Face_Part5.zip -d /content/drive/MyDrive/colab/test
# Out:
# Archive:  /content/drive/MyDrive/colab/Pgu-Face_Part1.zip
# replace /content/drive/MyDrive/colab/train/1/im01.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/colab/train/1/im01.jpg
# replace /content/drive/MyDrive/colab/train/1/img02.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/MyDrive/colab/train/1/img02.jpg
#   inflating: /content/drive/MyDrive/colab/train/1/img03.jpg
#   inflating: /content/drive/MyDrive/colab/train/1/img04.jpg
#  extracting: /content/drive/MyDrive/colab/train/1/text.txt
#   inflating: /content/drive/MyDrive/colab/train/2/img01.jpg
#   inflating: /content/drive/MyDrive/colab/train/2/img02.jpg
#   inflating: /content/drive/MyDrive/colab/train/2/img03.jpg
#   inflating: /content/drive/MyDrive/colab/train/2/img04.jpg
#  extracting: /content/drive/MyDrive/colab/train/2/text.txt
#   inflating: /content/drive/MyDrive/colab/train/3/img01.JPG
#   inflating: /content/drive/MyDrive/colab/train/3/img02.JPG
# ...

# %%
# !unrar x /content/drive/MyDrive/colab/Pgu-Face_Part4.rar /content/drive/MyDrive/colab/test
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/colab/Pgu-Face_Part4.rar
#
#
# Would you like to replace the existing file /content/drive/MyDrive/colab/test/131/img01.jpg
# 1164976 bytes, modified on 2013-04-27 00:20
# with a new one
# 1164976 bytes, modified on 2013-04-27 00:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit A
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

image_dir = Path('/content/drive/MyDrive/colab/train')

filepaths = pd.Series(list(image_dir.glob(r'**/*.*')), name='Filepath')
imagepaths = pd.Series(list(image_dir.glob(r'**/*.jpg')), name='Imagepath').astype(str)
agepaths = pd.Series(list(image_dir.glob(r'**/*.txt')), name='Agepath').astype(str)

index = 0
a=[]
textpaths = {}
for i in agepaths :
  f = open ( agepaths[index], 'r')
  f1 = f.readline()
  textpaths['age'] = f1.replace('Age:', '')
  textpaths['age'] = textpaths['age'].replace('Ag:', '')
  textpaths['age'] = textpaths['age'].replace('Age', '')
  textpaths['age'] = textpaths['age'].replace(':', '')
  textpaths['age'] = textpaths['age'].replace('age:', '')
  textpaths['age'] = textpaths['age'].replace('age', '')
  textpaths['age'] = textpaths['age'].replace('\n', '')
  textpaths['age'] = textpaths['age'].replace(' ', '')
  # a = i+'/'+f.readline()
  textpaths['path'] = i
  # print(textpaths)
  int(textpaths['age'])
  a.append(Path(i+'/'+textpaths['age']))
  index += 1
  # print(a)


agepath = pd.Series(list(a), name = 'AgePath' )

os.path.split(os.path.split(agepath.values[0])[1])[1]  #age
os.path.split(os.path.split(os.path.split(agepath.values[0])[0])[0])[1]  #folder
os.path.split(os.path.split(os.path.split(imagepaths.values[0])[0])[1])[1] #imagefolder
ages = pd.Series(agepath.apply(lambda x: os.path.split(os.path.split(os.path.split(x)[1])[1])[1]), name='Age').astype(int)


rows = []
for i in imagepaths:
  for j in agepath:
    if(os.path.split(os.path.split(os.path.split(i)[0])[1])[1] == os.path.split(os.path.split(os.path.split(j)[0])[0])[1]):
      #print(i + "+" + os.path.split(os.path.split(j)[1])[1])
      rows.append([i, os.path.split(os.path.split(j)[1])[1]])

images = pd.DataFrame(rows, columns=["ImagePath", "Age"]).sample(frac=1.0, random_state=1).reset_index(drop=True)
images["Age"] = images["Age"].astype(int)
type(images["ImagePath"][0])
# Out:
# str

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

image_dir = Path('/content/drive/MyDrive/colab/test')

filepaths = pd.Series(list(image_dir.glob(r'**/*.*')), name='Filepath')
imagepaths = pd.Series(list(image_dir.glob(r'**/*.jpg')), name='Imagepath').astype(str)
agepaths = pd.Series(list(image_dir.glob(r'**/*.txt')), name='Agepath').astype(str)

index = 0
a=[]
textpaths = {}
for i in agepaths :
  f = open ( agepaths[index], 'r')
  f1 = f.readline()
  textpaths['age'] = f1.replace('Age:', '')
  textpaths['age'] = textpaths['age'].replace('Ag:', '')
  textpaths['age'] = textpaths['age'].replace('Age', '')
  textpaths['age'] = textpaths['age'].replace(':', '')
  textpaths['age'] = textpaths['age'].replace('age:', '')
  textpaths['age'] = textpaths['age'].replace('age', '')
  textpaths['age'] = textpaths['age'].replace('\n', '')
  textpaths['age'] = textpaths['age'].replace(' ', '')
  # a = i+'/'+f.readline()
  textpaths['path'] = i
  # print(textpaths)
  int(textpaths['age'])
  a.append(Path(i+'/'+textpaths['age']))
  index += 1
  # print(a)


agepath = pd.Series(list(a), name = 'AgePath' )

os.path.split(os.path.split(agepath.values[0])[1])[1]  #age
os.path.split(os.path.split(os.path.split(agepath.values[0])[0])[0])[1]  #folder
os.path.split(os.path.split(os.path.split(imagepaths.values[0])[0])[1])[1] #imagefolder
ages = pd.Series(agepath.apply(lambda x: os.path.split(os.path.split(os.path.split(x)[1])[1])[1]), name='Age').astype(int)


rows = []
for i in imagepaths:
  for j in agepath:
    if(os.path.split(os.path.split(os.path.split(i)[0])[1])[1] == os.path.split(os.path.split(os.path.split(j)[0])[0])[1]):
      #print(i + "+" + os.path.split(os.path.split(j)[1])[1])
      rows.append([i, os.path.split(os.path.split(j)[1])[1]])

images_test = pd.DataFrame(rows, columns=["ImagePath", "Age"]).sample(frac=1.0, random_state=1).reset_index(drop=True)
images_test["Age"] = images_test["Age"].astype(int)
type(images_test["ImagePath"][0])
# Out:
# str

# %%
import torch
import torchvision.datasets as datasets
from torchvision import transforms
import cv2
import numpy as np

transform = transforms.Compose([transforms.ToTensor])

import torch
import torchvision
from PIL import Image


class MyDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe,transform = None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        row = self.dataframe.iloc[index]
        # image =  cv2.imread(row["ImagePath"],1)
        img = cv2.imread(row["ImagePath"], 1)
        img = cv2.resize(img, (224, 224))
        img = img.astype(np.float32)
        label = row["Age"]
        # label = age.to_numpy()
        # label = torch.from_numpy(label)

        if self.transform is not None:
          img = self.transform(img)
          # print(image.size())


          label = torchvision.transforms.functional.to_tensor(label)



        # return (image,label)
        return torch.from_numpy(np.transpose(img, (2, 0, 1))),label


trans = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])
dataset = MyDataset(images)
print(dataset)

ttrans = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])
Tdataset = MyDataset(images_test)
print(Tdataset)


# train = datasets.ImageFolder(images)
train_loader = torch.utils.data.DataLoader(dataset,batch_size=16)
test_loader = torch.utils.data.DataLoader(Tdataset,batch_size=16)

# %%
import torch.nn as nn
import pretrainedmodels
import pretrainedmodels.utils
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

def get_model(model_name="se_resnext50_32x4d", num_classes=101, pretrained="imagenet"):
    model = pretrainedmodels.__dict__[model_name](pretrained=pretrained)
    dim_feats = model.last_linear.in_features
    model.last_linear = nn.Linear(dim_feats, num_classes)
    model.avg_pool = nn.AdaptiveAvgPool2d(1)
    return model

model = get_model()
print(model)
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/se_resnext50_32x4d-a260b3a4.pth" to /root/.cache/torch/hub/checkpoints/se_resnext50_32x4d-a260b3a4.pth
# 100%|██████████| 105M/105M [05:10<00:00, 356kB/s]
# SENet(
#   (layer0): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   )
#   (layer1): Sequential(
#     (0): SEResNeXtBottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# ...

# %%
import argparse
#import better_exceptions
from pathlib import Path
from collections import OrderedDict
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
from torch.optim.lr_scheduler import StepLR
import torch.utils.data
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import pretrainedmodels
import pretrainedmodels.utils
from torch.utils.data import DataLoader
#from model import get_model
#from dataset import FaceDataset
#from defaults import _C as cfg

class AverageMeter(object):
    def __init__(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val
        self.count += n
        self.avg = self.sum / self.count


def train(train_loader, model, criterion, optimizer, epoch, device):
    model.train()
    loss_monitor = AverageMeter()
    accuracy_monitor = AverageMeter()

    with tqdm(train_loader) as _tqdm:
        for image, label in _tqdm:

          image = image.to(device)
          label = label.to(device)


            # compute output
          outputs = model(image)

            # calc loss
          loss = criterion(outputs, label)
          cur_loss = loss.item()

            # calc accuracy
          _, predicted = outputs.max(1)
          correct_num = predicted.eq(label).sum().item()

            # measure accuracy and record loss
          sample_num = image.size(0)
          loss_monitor.update(cur_loss, sample_num)
          accuracy_monitor.update(correct_num, sample_num)

            # compute gradient and do SGD step
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

          _tqdm.set_postfix(OrderedDict(stage="train", epoch=epoch, loss=loss_monitor.avg),
                              acc=accuracy_monitor.avg, correct=correct_num, sample_num=sample_num)

    return loss_monitor.avg, accuracy_monitor.avg


def validate(validate_loader, model, criterion, epoch, device):
    model.eval()
    loss_monitor = AverageMeter()
    accuracy_monitor = AverageMeter()
    preds = []
    gt = []

    with torch.no_grad():
        with tqdm(validate_loader) as _tqdm:
            for i, (x, y) in enumerate(_tqdm):
                x = x.to(device)
                y = y.to(device)

                # compute output
                outputs = model(x)
                preds.append(F.softmax(outputs, dim=-1).cpu().numpy())
                gt.append(y.cpu().numpy())

                # valid for validation, not used for test
                if criterion is not None:
                    # calc loss
                    loss = criterion(outputs, y)
                    cur_loss = loss.item()

                    # calc accuracy
                    _, predicted = outputs.max(1)
                    correct_num = predicted.eq(y).sum().item()

                    # measure accuracy and record loss
                    sample_num = x.size(0)
                    loss_monitor.update(cur_loss, sample_num)
                    accuracy_monitor.update(correct_num, sample_num)
                    _tqdm.set_postfix(OrderedDict(stage="val", epoch=epoch, loss=loss_monitor.avg),
                                      acc=accuracy_monitor.avg, correct=correct_num, sample_num=sample_num)

    preds = np.concatenate(preds, axis=0)
    gt = np.concatenate(gt, axis=0)
    ages = np.arange(0, 101)
    ave_preds = (preds * ages).sum(axis=-1)
    diff = ave_preds - gt
    mae = np.abs(diff).mean()

    return loss_monitor.avg, accuracy_monitor.avg, mae

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

epochs = 5

for epoch in range(epochs):
        # train
  train_loss, train_acc = train(train_loader, model, criterion, optimizer, epoch, device)

        # validate
  # val_loss, val_acc, val_mae = validate(val_loader, model, criterion, epoch, device)
# Out:
# ...
# 100%|██████████| 29/29 [00:36<00:00,  1.24s/it, stage=train, epoch=4, loss=0.0227, acc=0.912, correct=15, sample_num=16]

# %%
import argparse
#import better_exceptions
from pathlib import Path
from collections import OrderedDict
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
from torch.optim.lr_scheduler import StepLR
import torch.utils.data
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import pretrainedmodels
import pretrainedmodels.utils
from torch.utils.data import DataLoader
#from model import get_model
#from dataset import FaceDataset
#from defaults import _C as cfg


for epoch in range(5):
  val_loss, val_acc, val_mae = validate(test_loader, model, criterion, epoch, device)
# Out:
# ...
# 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, stage=val, epoch=4, loss=0.439, acc=0.0514, correct=0, sample_num=7]

# %%
# !exit
